# %% [markdown]
# Урок 1

# %%
  import numpy as np

# %%
from math import factorial

# %%
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# Задание 1.а

# %%
combinations(13,4)/combinations(52,4)
# Out:
# 0.0026410564225690276

# %% [markdown]
# Задание 1.б

# %%
1- combinations(48,4)/combinations(52,4)
# Out:
# 0.2812632745405854

# %% [markdown]
# Задание 2

# %%
combinations(10,3)
# Out:
# 120

# %% [markdown]
# Ответ: 1/120 или 0,0083

# %% [markdown]
# Задание 3

# %% [markdown]
# Ответ: (9/15) * (8/14) * (7/13) = (3/5) * (4/7) * (7/13)= 84/455 = 0.1846
#
# Или так:

# %%
combinations(9,3)/combinations(15,3)
# Out:
# 0.18461538461538463

# %% [markdown]
# Задание 4

# %%
combinations(100,2)
# Out:
# 4950

# %%
combinations(2,2)
# Out:
# 1

# %%
1/4950
# Out:
# 0.00020202020202020202

# %% [markdown]
# Ответ: 0.0002 или 1/4950
