# %%
import numpy as np
from math import factorial

def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# Задание 3.1

# %%
salary = [100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150]
# среднее арифметическое
mean = sum(salary)/len(salary)
mean
# Out:
# 65.3

# %%
# смещённая оценка дисперсии
variance = sum([((x - mean) ** 2) for x in salary]) / len(salary)
variance
# Out:
# 950.11

# %%
# среднее квадратичное отклонение
std = variance ** 0.5
std
# Out:
# 30.823854398825596

# %%
# несмещённая оценка дисперсии
variance_n = sum([((x - mean) ** 2) for x in salary]) / (len(salary)-1)
variance_n
# Out:
# 1000.1157894736842

# %% [markdown]
# Задание 3.2

# %%
#Общее количество комбинаций
C = combinations(8,2)*combinations(12,4)
# 0 шаров из первого ящика
p1 = combinations(5,0)*combinations(3,2)*combinations(5,3)*combinations(7,1)/C
# 1 шар из первого ящика
p2 = combinations(5,1)*combinations(3,1)*combinations(5,2)*combinations(7,2)/C
# 2 шара из первого ящика
p3 = combinations(5,2)*combinations(3,0)*combinations(5,1)*combinations(7,3)/C
P = p1+p2+p3
P
# Out:
# 0.36868686868686873

# %% [markdown]
# Задание 3.3

# %%
p_B1 = 0.9
p_B2 = 0.8
p_B3 = 0.6
p_A = (p_B1+p_B2+p_B3)/3

# %%
# а)
p1 = p_B1/3/p_A
p1
# Out:
# 0.3913043478260869

# %%
# б)
p2 = p_B2/3/p_A
p2
# Out:
# 0.34782608695652173

# %%
# в)
p3 = p_B3/3/p_A
p3
# Out:
# 0.26086956521739124

# %% [markdown]
# Задание 4

# %%
p_B1 = 0.8
p_B2 = 0.7
p_B3 = 0.9
# событие А - успешная сдача сессии
p_A = 1/4*p_B1+1/4*p_B2+1/2*p_B3

# %%
# а) Вероятность,что студент учится на факультете А
p1 = p_B1/4/p_A
p1
# Out:
# 0.24242424242424246

# %%
# б) Вероятность,что студент учится на факультете B
p2 = p_B2/4/p_A
p2
# Out:
# 0.21212121212121213

# %%
# в) Вероятность,что студент учится на факультете C
p3 = p_B3/2/p_A
p3
# Out:
# 0.5454545454545455

# %% [markdown]
# Задание 5

# %%
# p - вероятность что деталь выходит из строя. q - вероятность, что не выходит (1-p)
p1 = 0.1
p2 = 0.2
p3 = 0.25
q1 = 0.9
q2 = 0.8
q3 = 0.75

# %%
# а) Вероятность выхода из строя всех деталей
p1*p2*p3
# Out:
# 0.005000000000000001

# %%
# б) Вероятность выхода из строя только двух деталей
p1*p2*q3 + p1*q2*p3 + q1*p2*p3
# Out:
# 0.08000000000000002

# %%
# в) Вероятность выхода из строя хотя бы одной детали
p1*q2*q3 + q1*p2*q3 + q1*q2*p3
# Out:
# 0.375

# %%
# г) Вероятность выхода из строя от одной до двух деталей (1 - вероятность, что три детали работают - вероятность, что три детали вышли из строя)

# %%
1 - q1*q2*q3-p1*p2*p3
# Out:
# 0.45499999999999996
